# %%
import os
os.chdir("..")
os.getcwd
# Out:
# <function posix.getcwd()>

# %%
from os.path import join

import pandas as pd

import torchaudio

# %%
dataset_path = "temp_datasets/alip_sample"
annotations = pd.read_csv(join(dataset_path,"annotations.csv"))

# %%
annotations["duration"].plot(kind="box")
# Out:
# <Axes: >

# %%
q_low = annotations["duration"].quantile(0.01)
q_hi  = annotations["duration"].quantile(0.99)

annotations = annotations[(annotations["duration"] < q_hi) & (annotations["duration"] > q_low)]

# %%
annotations["duration"].plot(kind="box")
# Out:
# <Axes: >
